# %% [markdown]
# ### Irrigation model input file prep
#
# This code prepares the final input file to the irrigation (agrodem) model. It extracts all necessary attributes to crop locations. It also applies some name fixes as needed for the model to run smoothly.The output dataframe is exported as csv and ready to be used in the irrigation model.
#
# **Original code:** [Alexandros Korkovelos](https://github.com/akorkovelos) & [Konstantinos Pegios](https://github.com/kopegios)<br />
# **Conceptualization & Methodological review :** [Alexandros Korkovelos](https://github.com/akorkovelos)<br />
# **Updates, Modifications:** [Alexandros Korkovelos](https://github.com/akorkovelos)<br />
# **Funding:** The World Bank (contract number: 7190531), [KTH](https://www.kth.se/en/itm/inst/energiteknik/forskning/desa/welcome-to-the-unit-of-energy-systems-analysis-kth-desa-1.197296)

# %%
#Import modules and libraries
import os
import geopandas as gpd
from rasterstats import point_query
import logging
import pandas as pd
from shapely.geometry import Point, Polygon
import gdal
import rasterio as rio
import fiona
import gdal
import osr
import ogr
import rasterio.mask
import time
import numpy as np
import itertools
import re
from osgeo import gdal,ogr
import struct
import csv
import tkinter as tk
from tkinter import filedialog, messagebox
from pandas import DataFrame as df
from rasterio.warp import calculate_default_transform, reproject
from rasterio.enums import Resampling
from rasterstats import point_query
from pyproj import Proj
from shapely.geometry import Point, Polygon

# %%
# Import data 

root = tk.Tk()
root.withdraw()
root.attributes("-topmost", True)
messagebox.showinfo('Agrodem Prepping', 'Open the extracted csv file obtained after running the QGIS plugin - surface water extractor')
input_file = filedialog.askopenfilename()

# Import csv as pandas dataframe
crop_df = pd.read_csv(input_file)

# %%
# Fill in Nan values with 0
crop_df.fillna(99999,inplace=True)
crop_df.head(2)
# Out:
#   country_co  country admin2       _mean  alloc_key   cell5m          x  \
# 0        SOM  Somalia   Baki  256.933333    9602681  4145560  43.375000
# 1        SOM  Somalia   Baki  256.933333    9602682  4145561  43.458333
#
#            y  harea_spam name_cntr  shareofsum   harv_area_   district_a  \
# 0  10.041667      1089.4   Somalia    0.005071  1188.752358  369427.2535
# 1  10.041667         0.0   Somalia    0.000000     0.000000  369427.2535
#
#    shareofdis   elevation
# 0    0.003218  565.677688
# 1    0.000000  565.677688

# %%
crop_df.columns
# Out:
# Index(['country_co', 'country', 'admin2', '_mean', 'alloc_key', 'cell5m', 'x',
#        'y', 'harea_spam', 'name_cntr', 'shareofsum', 'harv_area_',
#        'district_a', 'shareofdis', 'elevation'],
#       dtype='object')

# %%
#somalia only
crop_df=crop_df.drop(['district_a', 'shareofdis','_mean', 'alloc_key', 'cell5m','country_co', 'country','name_cntr', 'shareofsum', 'harea_spam'],axis = 1)

# %%
#somalia only
crop_df.rename(columns={'elevation': 'sw_depth',
                         'harv_area_': 'harv_area',
                       'admin2':'state',
                       'x':'lon',
                       'y':'lat'}, inplace=True)

# %%
crop_df.columns
# Out:
# Index(['state', 'lon', 'lat', 'harv_area', 'sw_depth'], dtype='object')

# %%
##Dropping unecessary columns

droping_cols = ['Pixel']
crop_df.drop(droping_cols, axis=1)

# New for whole Moz
crop_df.rename(columns={'elevation': 'sw_depth',
                         'CropArea': 'harv_area'}, inplace=True)

# Adding columns missing
crop_df["country"] = "Somalia"
crop_df["curr_yield"] = "580"
crop_df["max_yield"] = "1493"
crop_df['field_1'] = range(0, 0+len(crop_df))

# %%
#Somalia
#Adding columns missing
crop_df["country"] = "Somalia"
crop_df["curr_yield"] = "360"
crop_df["max_yield"] = "552.6"
crop_df['field_1'] = range(0, 0+len(crop_df))

# %% [markdown]
# #### Converting dataframe to geo-dataframe

# %%
# Add geometry and convert to spatial dataframe in source CRS
crop_df['geometry'] = list(zip(crop_df['lon'], crop_df['lat']))
crop_df['geometry'] = crop_df['geometry'].apply(Point)
crop_df = gpd.GeoDataFrame(crop_df, geometry='geometry', crs={'init': 'epsg:4326'})

#Reproject data in to Ordnance Survey GB coordinates
crop_df = crop_df.to_crs({'init': 'epsg:4326'})
# Out:
# C:\Users\adm.esa\Anaconda3\envs\OSMNX\lib\site-packages\pyproj\crs\crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# convert to shapefile
#write the name you would like to have in the string "test_final5, you can keep this also as the default name"
crop_df.to_file('Sorghum_Somalia_10km.shp',driver = 'ESRI Shapefile')

# %%
#export to csv
messagebox.showinfo('Agrodem Prepping','Browse to the folder where you want to save geodataframe as a csv file')
path = filedialog.askdirectory()
shpname = 'Sorghum_Somalia_10km'
crop_df.to_csv(os.path.join(path,"{}.csv".format(shpname)))

# %%
messagebox.showinfo('Agrodem Prepping', 'Browse to the folder that contains required Raster files for temp, prec and radiance')
#file location: r"N:\Agrodem\Irrigation_model\Input_data\Supporting_Layers"
raster_path = filedialog.askdirectory()
raster_files =[]
print ("Reading independent variables...")

for i in os.listdir(raster_path):
    if i.endswith('.tif'):
        raster_files.append(i) 
messagebox.showinfo('Agrodem Prepping','Open the saved shapefile extracted from the input csv file above ')       
shp_filename = filedialog.askopenfilename()


print ("Extracting raster values to points...")

for i in raster_files:
    print("Extracting " + i + " values...")
    src_filename = raster_path + "\\" + i 
    li_values = list()

    src_ds=gdal.Open(src_filename) 
    gt=src_ds.GetGeoTransform()
    rb=src_ds.GetRasterBand(1)
    ds=ogr.Open(shp_filename)
    lyr=ds.GetLayer()
    
    for feat in lyr:
        geom = feat.GetGeometryRef()
        feat_id = feat.GetField('field_1')
        mx,my=geom.GetX(), geom.GetY()  #coord in map units

        #Convert from map to pixel coordinates.
        #Only works for geotransforms with no rotation.
        px = int((mx - gt[0]) / gt[1]) #x pixel
        py = int((my - gt[3]) / gt[5]) #y pixel

        intval=rb.ReadAsArray(px,py,1,1)
        li_values.append([feat_id, intval[0]])
        
    print ("Writing " + i + " values to csv...")
    
    #input to the output folder for generated csv files
    
    csvoutpath = r"C:\Irrigation_Model\Somalia\Sorghum"    
    
    with open(csvoutpath + "\\" + i.split('.')[0] + i.split('.')[1] + '.csv', 'w') as csvfile:
        wr = csv.writer(csvfile)
        wr.writerows(li_values)
# Out:
# Reading independent variables...
# Extracting raster values to points...
# Extracting elevation.tif values...
# Writing elevation.tif values to csv...
# Extracting gyga_af_agg_erzd_tawcpf23mm__m_1km.tif values...
# Writing gyga_af_agg_erzd_tawcpf23mm__m_1km.tif values to csv...
# Extracting wc2.0_30s_prec_01.tif values...
# Writing wc2.0_30s_prec_01.tif values to csv...
# Extracting wc2.0_30s_prec_02.tif values...
# Writing wc2.0_30s_prec_02.tif values to csv...
# Extracting wc2.0_30s_prec_03.tif values...
# Writing wc2.0_30s_prec_03.tif values to csv...
# Extracting wc2.0_30s_prec_04.tif values...
# Writing wc2.0_30s_prec_04.tif values to csv...
# Extracting wc2.0_30s_prec_05.tif values...
# Writing wc2.0_30s_prec_05.tif values to csv...
# Extracting wc2.0_30s_prec_06.tif values...
# Writing wc2.0_30s_prec_06.tif values to csv...
# Extracting wc2.0_30s_prec_07.tif values...
# Writing wc2.0_30s_prec_07.tif values to csv...
# Extracting wc2.0_30s_prec_08.tif values...
# Writing wc2.0_30s_prec_08.tif values to csv...
# Extracting wc2.0_30s_prec_09.tif values...
# Writing wc2.0_30s_prec_09.tif values to csv...
# Extracting wc2.0_30s_prec_10.tif values...
# Writing wc2.0_30s_prec_10.tif values to csv...
# Extracting wc2.0_30s_prec_11.tif values...
# Writing wc2.0_30s_prec_11.tif values to csv...
# Extracting wc2.0_30s_prec_12.tif values...
# Writing wc2.0_30s_prec_12.tif values to csv...
# Extracting wc2.0_30s_srad_01.tif values...
# Writing wc2.0_30s_srad_01.tif values to csv...
# Extracting wc2.0_30s_srad_02.tif values...
# Writing wc2.0_30s_srad_02.tif values to csv...
# Extracting wc2.0_30s_srad_03.tif values...
# Writing wc2.0_30s_srad_03.tif values to csv...
# Extracting wc2.0_30s_srad_04.tif values...
# Writing wc2.0_30s_srad_04.tif values to csv...
# Extracting wc2.0_30s_srad_05.tif values...
# Writing wc2.0_30s_srad_05.tif values to csv...
# Extracting wc2.0_30s_srad_06.tif values...
# Writing wc2.0_30s_srad_06.tif values to csv...
# Extracting wc2.0_30s_srad_07.tif values...
# Writing wc2.0_30s_srad_07.tif values to csv...
# Extracting wc2.0_30s_srad_08.tif values...
# Writing wc2.0_30s_srad_08.tif values to csv...
# Extracting wc2.0_30s_srad_09.tif values...
# Writing wc2.0_30s_srad_09.tif values to csv...
# Extracting wc2.0_30s_srad_10.tif values...
# Writing wc2.0_30s_srad_10.tif values to csv...
# Extracting wc2.0_30s_srad_11.tif values...
# Writing wc2.0_30s_srad_11.tif values to csv...
# Extracting wc2.0_30s_srad_12.tif values...
# Writing wc2.0_30s_srad_12.tif values to csv...
# Extracting wc2.0_30s_tavg_01.tif values...
# Writing wc2.0_30s_tavg_01.tif values to csv...
# Extracting wc2.0_30s_tavg_02.tif values...
# Writing wc2.0_30s_tavg_02.tif values to csv...
# Extracting wc2.0_30s_tavg_03.tif values...
# Writing wc2.0_30s_tavg_03.tif values to csv...
# Extracting wc2.0_30s_tavg_04.tif values...
# Writing wc2.0_30s_tavg_04.tif values to csv...
# Extracting wc2.0_30s_tavg_05.tif values...
# Writing wc2.0_30s_tavg_05.tif values to csv...
# Extracting wc2.0_30s_tavg_06.tif values...
# Writing wc2.0_30s_tavg_06.tif values to csv...
# Extracting wc2.0_30s_tavg_07.tif values...
# Writing wc2.0_30s_tavg_07.tif values to csv...
# Extracting wc2.0_30s_tavg_08.tif values...
# Writing wc2.0_30s_tavg_08.tif values to csv...
# Extracting wc2.0_30s_tavg_09.tif values...
# Writing wc2.0_30s_tavg_09.tif values to csv...
# Extracting wc2.0_30s_tavg_10.tif values...
# Writing wc2.0_30s_tavg_10.tif values to csv...
# Extracting wc2.0_30s_tavg_11.tif values...
# Writing wc2.0_30s_tavg_11.tif values to csv...
# Extracting wc2.0_30s_tavg_12.tif values...
# Writing wc2.0_30s_tavg_12.tif values to csv...
# Extracting wc2.0_30s_tmax_01.tif values...
# Writing wc2.0_30s_tmax_01.tif values to csv...
# Extracting wc2.0_30s_tmax_02.tif values...
# Writing wc2.0_30s_tmax_02.tif values to csv...
# Extracting wc2.0_30s_tmax_03.tif values...
# Writing wc2.0_30s_tmax_03.tif values to csv...
# Extracting wc2.0_30s_tmax_04.tif values...
# Writing wc2.0_30s_tmax_04.tif values to csv...
# Extracting wc2.0_30s_tmax_05.tif values...
# Writing wc2.0_30s_tmax_05.tif values to csv...
# Extracting wc2.0_30s_tmax_06.tif values...
# Writing wc2.0_30s_tmax_06.tif values to csv...
# Extracting wc2.0_30s_tmax_07.tif values...
# Writing wc2.0_30s_tmax_07.tif values to csv...
# Extracting wc2.0_30s_tmax_08.tif values...
# Writing wc2.0_30s_tmax_08.tif values to csv...
# Extracting wc2.0_30s_tmax_09.tif values...
# Writing wc2.0_30s_tmax_09.tif values to csv...
# Extracting wc2.0_30s_tmax_10.tif values...
# Writing wc2.0_30s_tmax_10.tif values to csv...
# Extracting wc2.0_30s_tmax_11.tif values...
# Writing wc2.0_30s_tmax_11.tif values to csv...
# Extracting wc2.0_30s_tmax_12.tif values...
# Writing wc2.0_30s_tmax_12.tif values to csv...
# Extracting wc2.0_30s_tmin_01.tif values...
# Writing wc2.0_30s_tmin_01.tif values to csv...
# Extracting wc2.0_30s_tmin_02.tif values...
# Writing wc2.0_30s_tmin_02.tif values to csv...
# Extracting wc2.0_30s_tmin_03.tif values...
# Writing wc2.0_30s_tmin_03.tif values to csv...
# Extracting wc2.0_30s_tmin_04.tif values...
# Writing wc2.0_30s_tmin_04.tif values to csv...
# Extracting wc2.0_30s_tmin_05.tif values...
# Writing wc2.0_30s_tmin_05.tif values to csv...
# Extracting wc2.0_30s_tmin_06.tif values...
# Writing wc2.0_30s_tmin_06.tif values to csv...
# Extracting wc2.0_30s_tmin_07.tif values...
# Writing wc2.0_30s_tmin_07.tif values to csv...
# Extracting wc2.0_30s_tmin_08.tif values...
# Writing wc2.0_30s_tmin_08.tif values to csv...
# Extracting wc2.0_30s_tmin_09.tif values...
# Writing wc2.0_30s_tmin_09.tif values to csv...
# Extracting wc2.0_30s_tmin_10.tif values...
# Writing wc2.0_30s_tmin_10.tif values to csv...
# Extracting wc2.0_30s_tmin_11.tif values...
# Writing wc2.0_30s_tmin_11.tif values to csv...
# Extracting wc2.0_30s_tmin_12.tif values...
# Writing wc2.0_30s_tmin_12.tif values to csv...
# Extracting wc2.0_30s_wind_01.tif values...
# Writing wc2.0_30s_wind_01.tif values to csv...
# Extracting wc2.0_30s_wind_02.tif values...
# Writing wc2.0_30s_wind_02.tif values to csv...
# Extracting wc2.0_30s_wind_03.tif values...
# Writing wc2.0_30s_wind_03.tif values to csv...
# Extracting wc2.0_30s_wind_04.tif values...
# Writing wc2.0_30s_wind_04.tif values to csv...
# Extracting wc2.0_30s_wind_05.tif values...
# Writing wc2.0_30s_wind_05.tif values to csv...
# Extracting wc2.0_30s_wind_06.tif values...
# Writing wc2.0_30s_wind_06.tif values to csv...
# Extracting wc2.0_30s_wind_07.tif values...
# Writing wc2.0_30s_wind_07.tif values to csv...
# Extracting wc2.0_30s_wind_08.tif values...
# Writing wc2.0_30s_wind_08.tif values to csv...
# Extracting wc2.0_30s_wind_09.tif values...
# Writing wc2.0_30s_wind_09.tif values to csv...
# Extracting wc2.0_30s_wind_10.tif values...
# Writing wc2.0_30s_wind_10.tif values to csv...
# Extracting wc2.0_30s_wind_11.tif values...
# Writing wc2.0_30s_wind_11.tif values to csv...
# Extracting wc2.0_30s_wind_12.tif values...
# Writing wc2.0_30s_wind_12.tif values to csv...
# Extracting WTD.tif values...
# Writing WTD.tif values to csv...

# %% [markdown]
# ## Merge csv files with crop

# %%
#Import data 

messagebox.showinfo('Agrodem Prepping', 'Open the csv file you in which you exported the geodataframe previously')
file = filedialog.askopenfilename()
agrodem_input = pd.read_csv(file)

# %%
csv_files = []

print ("Reading csv files...")

for i in os.listdir(csvoutpath):
    if i.endswith('.csv'):
        csv_files.append(i)  

for i in csv_files:
    print('Reading...'+ i)    
    df_csv = pd.read_csv(csvoutpath + "//" + i, index_col=None, header=None)
    df_csv.iloc[:,1] = df_csv.iloc[:,1].astype(str)
    df_csv.iloc[:,1] = df_csv.iloc[:,1].str.replace('[','')
    df_csv.iloc[:,1] = df_csv.iloc[:,1].str.replace(']','')
    columnName = i.split('.')[0]
    
    print("Merging..." + columnName)
    agrodem_input[columnName] = df_csv.iloc[:,1]
# Out:
# Reading csv files...
# Reading...elevationtif.csv
# Merging...elevationtif
# Reading...gyga_af_agg_erzd_tawcpf23mm__m_1kmtif.csv
# Merging...gyga_af_agg_erzd_tawcpf23mm__m_1kmtif
# Reading...wc20_30s_prec_01.csv
# Merging...wc20_30s_prec_01
# Reading...wc20_30s_prec_02.csv
# Merging...wc20_30s_prec_02
# Reading...wc20_30s_prec_03.csv
# Merging...wc20_30s_prec_03
# Reading...wc20_30s_prec_04.csv
# Merging...wc20_30s_prec_04
# Reading...wc20_30s_prec_05.csv
# Merging...wc20_30s_prec_05
# Reading...wc20_30s_prec_06.csv
# Merging...wc20_30s_prec_06
# Reading...wc20_30s_prec_07.csv
# Merging...wc20_30s_prec_07
# Reading...wc20_30s_prec_08.csv
# Merging...wc20_30s_prec_08
# Reading...wc20_30s_prec_09.csv
# Merging...wc20_30s_prec_09
# Reading...wc20_30s_prec_10.csv
# Merging...wc20_30s_prec_10
# Reading...wc20_30s_prec_11.csv
# Merging...wc20_30s_prec_11
# Reading...wc20_30s_prec_12.csv
# Merging...wc20_30s_prec_12
# Reading...wc20_30s_srad_01.csv
# Merging...wc20_30s_srad_01
# Reading...wc20_30s_srad_02.csv
# Merging...wc20_30s_srad_02
# Reading...wc20_30s_srad_03.csv
# Merging...wc20_30s_srad_03
# Reading...wc20_30s_srad_04.csv
# Merging...wc20_30s_srad_04
# Reading...wc20_30s_srad_05.csv
# Merging...wc20_30s_srad_05
# Reading...wc20_30s_srad_06.csv
# Merging...wc20_30s_srad_06
# Reading...wc20_30s_srad_07.csv
# Merging...wc20_30s_srad_07
# Reading...wc20_30s_srad_08.csv
# Merging...wc20_30s_srad_08
# Reading...wc20_30s_srad_09.csv
# Merging...wc20_30s_srad_09
# Reading...wc20_30s_srad_10.csv
# Merging...wc20_30s_srad_10
# Reading...wc20_30s_srad_11.csv
# Merging...wc20_30s_srad_11
# Reading...wc20_30s_srad_12.csv
# Merging...wc20_30s_srad_12
# Reading...wc20_30s_tavg_01.csv
# Merging...wc20_30s_tavg_01
# Reading...wc20_30s_tavg_02.csv
# Merging...wc20_30s_tavg_02
# Reading...wc20_30s_tavg_03.csv
# Merging...wc20_30s_tavg_03
# Reading...wc20_30s_tavg_04.csv
# Merging...wc20_30s_tavg_04
# Reading...wc20_30s_tavg_05.csv
# Merging...wc20_30s_tavg_05
# Reading...wc20_30s_tavg_06.csv
# Merging...wc20_30s_tavg_06
# Reading...wc20_30s_tavg_07.csv
# Merging...wc20_30s_tavg_07
# Reading...wc20_30s_tavg_08.csv
# Merging...wc20_30s_tavg_08
# Reading...wc20_30s_tavg_09.csv
# Merging...wc20_30s_tavg_09
# Reading...wc20_30s_tavg_10.csv
# Merging...wc20_30s_tavg_10
# Reading...wc20_30s_tavg_11.csv
# Merging...wc20_30s_tavg_11
# Reading...wc20_30s_tavg_12.csv
# Merging...wc20_30s_tavg_12
# Reading...wc20_30s_tmax_01.csv
# Merging...wc20_30s_tmax_01
# Reading...wc20_30s_tmax_02.csv
# Merging...wc20_30s_tmax_02
# Reading...wc20_30s_tmax_03.csv
# Merging...wc20_30s_tmax_03
# Reading...wc20_30s_tmax_04.csv
# Merging...wc20_30s_tmax_04
# Reading...wc20_30s_tmax_05.csv
# Merging...wc20_30s_tmax_05
# Reading...wc20_30s_tmax_06.csv
# Merging...wc20_30s_tmax_06
# Reading...wc20_30s_tmax_07.csv
# Merging...wc20_30s_tmax_07
# Reading...wc20_30s_tmax_08.csv
# Merging...wc20_30s_tmax_08
# Reading...wc20_30s_tmax_09.csv
# Merging...wc20_30s_tmax_09
# Reading...wc20_30s_tmax_10.csv
# Merging...wc20_30s_tmax_10
# Reading...wc20_30s_tmax_11.csv
# Merging...wc20_30s_tmax_11
# Reading...wc20_30s_tmax_12.csv
# Merging...wc20_30s_tmax_12
# Reading...wc20_30s_tmin_01.csv
# Merging...wc20_30s_tmin_01
# Reading...wc20_30s_tmin_02.csv
# Merging...wc20_30s_tmin_02
# Reading...wc20_30s_tmin_03.csv
# Merging...wc20_30s_tmin_03
# Reading...wc20_30s_tmin_04.csv
# Merging...wc20_30s_tmin_04
# Reading...wc20_30s_tmin_05.csv
# Merging...wc20_30s_tmin_05
# Reading...wc20_30s_tmin_06.csv
# Merging...wc20_30s_tmin_06
# Reading...wc20_30s_tmin_07.csv
# Merging...wc20_30s_tmin_07
# Reading...wc20_30s_tmin_08.csv
# Merging...wc20_30s_tmin_08
# Reading...wc20_30s_tmin_09.csv
# Merging...wc20_30s_tmin_09
# Reading...wc20_30s_tmin_10.csv
# Merging...wc20_30s_tmin_10
# Reading...wc20_30s_tmin_11.csv
# Merging...wc20_30s_tmin_11
# Reading...wc20_30s_tmin_12.csv
# Merging...wc20_30s_tmin_12
# Reading...wc20_30s_wind_01.csv
# Merging...wc20_30s_wind_01
# Reading...wc20_30s_wind_02.csv
# Merging...wc20_30s_wind_02
# Reading...wc20_30s_wind_03.csv
# Merging...wc20_30s_wind_03
# Reading...wc20_30s_wind_04.csv
# Merging...wc20_30s_wind_04
# Reading...wc20_30s_wind_05.csv
# Merging...wc20_30s_wind_05
# Reading...wc20_30s_wind_06.csv
# Merging...wc20_30s_wind_06
# Reading...wc20_30s_wind_07.csv
# Merging...wc20_30s_wind_07
# Reading...wc20_30s_wind_08.csv
# Merging...wc20_30s_wind_08
# Reading...wc20_30s_wind_09.csv
# Merging...wc20_30s_wind_09
# Reading...wc20_30s_wind_10.csv
# Merging...wc20_30s_wind_10
# Reading...wc20_30s_wind_11.csv
# Merging...wc20_30s_wind_11
# Reading...wc20_30s_wind_12.csv
# Merging...wc20_30s_wind_12
# Reading...WTDtif.csv
# Merging...WTDtif

# %%
# Define output path
# Overwriting the csv file
#path = r"N:\Agrodem\Irrigation_model\Output_data\agrodem_input"
path = r"F:\AgriDem\agrodem_preprocessing\Agrodem_prepping_output"
shpname = "Sorghum_Somalia_10km.csv"

#maize
crop_df.to_csv(os.path.join(path,"{c}".format(c=shpname)))

# %%
agrodem_input.columns
# Out:
# Index(['Unnamed: 0', 'state', 'lon', 'lat', 'harv_area', 'sw_depth', 'country',
#        'curr_yield', 'max_yield', 'field_1', 'geometry', 'elevationtif',
#        'gyga_af_agg_erzd_tawcpf23mm__m_1kmtif', 'wc20_30s_prec_01',
#        'wc20_30s_prec_02', 'wc20_30s_prec_03', 'wc20_30s_prec_04',
#        'wc20_30s_prec_05', 'wc20_30s_prec_06', 'wc20_30s_prec_07',
#        'wc20_30s_prec_08', 'wc20_30s_prec_09', 'wc20_30s_prec_10',
#        'wc20_30s_prec_11', 'wc20_30s_prec_12', 'wc20_30s_srad_01',
#        'wc20_30s_srad_02', 'wc20_30s_srad_03', 'wc20_30s_srad_04',
#        'wc20_30s_srad_05', 'wc20_30s_srad_06', 'wc20_30s_srad_07',
#        'wc20_30s_srad_08', 'wc20_30s_srad_09', 'wc20_30s_srad_10',
#        'wc20_30s_srad_11', 'wc20_30s_srad_12', 'wc20_30s_tavg_01',
#        'wc20_30s_tavg_02', 'wc20_30s_tavg_03', 'wc20_30s_tavg_04',
#        'wc20_30s_tavg_05', 'wc20_30s_tavg_06', 'wc20_30s_tavg_07',
#        'wc20_30s_tavg_08', 'wc20_30s_tavg_09', 'wc20_30s_tavg_10',
#        'wc20_30s_tavg_11', 'wc20_30s_tavg_12', 'wc20_30s_tmax_01',
#        'wc20_30s_tmax_02', 'wc20_30s_tmax_03', 'wc20_30s_tmax_04',
#        'wc20_30s_tmax_05', 'wc20_30s_tmax_06', 'wc20_30s_tmax_07',
#        'wc20_30s_tmax_08', 'wc20_30s_tmax_09', 'wc20_30s_tmax_10',
#        'wc20_30s_tmax_11', 'wc20_30s_tmax_12', 'wc20_30s_tmin_01',
#        'wc20_30s_tmin_02', 'wc20_30s_tmin_03', 'wc20_30s_tmin_04',
#        'wc20_30s_tmin_05', 'wc20_30s_tmin_06', 'wc20_30s_tmin_07',
#        'wc20_30s_tmin_08', 'wc20_30s_tmin_09', 'wc20_30s_tmin_10',
#        'wc20_30s_tmin_11', 'wc20_30s_tmin_12', 'wc20_30s_wind_01',
#        'wc20_30s_wind_02', 'wc20_30s_wind_03', 'wc20_30s_wind_04',
#        'wc20_30s_wind_05', 'wc20_30s_wind_06', 'wc20_30s_wind_07',
#        'wc20_30s_wind_08', 'wc20_30s_wind_09', 'wc20_30s_wind_10',
#        'wc20_30s_wind_11', 'wc20_30s_wind_12', 'WTDtif'],
#       dtype='object')

# %% [markdown]
# ### Updated names of input files for 30s rasters

# %%
# Renaming columns as input file requires
agrodem_input.rename(columns={'wc20_30s_prec_01': 'prec_1',
                              'wc20_30s_prec_02': 'prec_2', 
                              'wc20_30s_prec_03': 'prec_3', 
                              'wc20_30s_prec_04': 'prec_4',
                              'wc20_30s_prec_05': 'prec_5', 
                              'wc20_30s_prec_06': 'prec_6', 
                              'wc20_30s_prec_07': 'prec_7',
                              'wc20_30s_prec_08': 'prec_8', 
                              'wc20_30s_prec_09': 'prec_9', 
                              'wc20_30s_prec_10': 'prec_10',
                              'wc20_30s_prec_11': 'prec_11', 
                              'wc20_30s_prec_12': 'prec_12', 
                              'wc20_30s_srad_01': 'srad_1',
                              'wc20_30s_srad_02': 'srad_2', 
                              'wc20_30s_srad_03': 'srad_3', 
                              'wc20_30s_srad_04': 'srad_4',
                              'wc20_30s_srad_05': 'srad_5', 
                              'wc20_30s_srad_06': 'srad_6', 
                              'wc20_30s_srad_07': 'srad_7',
                              'wc20_30s_srad_08': 'srad_8', 
                              'wc20_30s_srad_09': 'srad_9', 
                              'wc20_30s_srad_10': 'srad_10',
                              'wc20_30s_srad_11': 'srad_11', 
                              'wc20_30s_srad_12': 'srad_12', 
                              'wc20_30s_tavg_01': 'tavg_1',
                              'wc20_30s_tavg_02': 'tavg_2', 
                              'wc20_30s_tavg_03': 'tavg_3', 
                              'wc20_30s_tavg_04': 'tavg_4',
                              'wc20_30s_tavg_05': 'tavg_5', 
                              'wc20_30s_tavg_06': 'tavg_6', 
                              'wc20_30s_tavg_07': 'tavg_7',
                              'wc20_30s_tavg_08': 'tavg_8',
                              'wc20_30s_tavg_09': 'tavg_9', 
                              'wc20_30s_tavg_10': 'tavg_10',
                              'wc20_30s_tavg_11': 'tavg_11', 
                              'wc20_30s_tavg_12': 'tavg_12', 
                              'wc20_30s_tmax_01': 'tmax_1',
                              'wc20_30s_tmax_02': 'tmax_2', 
                              'wc20_30s_tmax_03': 'tmax_3', 
                              'wc20_30s_tmax_04': 'tmax_4',
                              'wc20_30s_tmax_05': 'tmax_5', 
                              'wc20_30s_tmax_06': 'tmax_6', 
                              'wc20_30s_tmax_07': 'tmax_7',
                              'wc20_30s_tmax_08': 'tmax_8', 
                              'wc20_30s_tmax_09': 'tmax_9', 
                              'wc20_30s_tmax_10': 'tmax_10',
                              'wc20_30s_tmax_11': 'tmax_11', 
                              'wc20_30s_tmax_12': 'tmax_12',
                              'wc20_30s_tmin_01': 'tmin_1',
                              'wc20_30s_tmin_02': 'tmin_2', 
                              'wc20_30s_tmin_03': 'tmin_3', 
                              'wc20_30s_tmin_04': 'tmin_4',
                              'wc20_30s_tmin_05': 'tmin_5', 
                              'wc20_30s_tmin_06': 'tmin_6', 
                              'wc20_30s_tmin_07': 'tmin_7',
                              'wc20_30s_tmin_08': 'tmin_8', 
                              'wc20_30s_tmin_09': 'tmin_9', 
                              'wc20_30s_tmin_10': 'tmin_10',
                              'wc20_30s_tmin_11': 'tmin_11', 
                              'wc20_30s_tmin_12': 'tmin_12', 
                              'wc20_30s_wind_01': 'wind_1',
                              'wc20_30s_wind_02': 'wind_2', 
                              'wc20_30s_wind_03': 'wind_3', 
                              'wc20_30s_wind_04': 'wind_4',
                              'wc20_30s_wind_05': 'wind_5', 
                              'wc20_30s_wind_06': 'wind_6', 
                              'wc20_30s_wind_07': 'wind_7',
                              'wc20_30s_wind_08': 'wind_8', 
                              'wc20_30s_wind_09': 'wind_9', 
                              'wc20_30s_wind_10': 'wind_10',
                              'wc20_30s_wind_11': 'wind_11', 
                              'wc20_30s_wind_12': 'wind_12',
                              'gyga_af_agg_erzd_tawcpf23mm__m_1kmtif': 'awsc',
                              'elevationtif': 'elevation',
                              'WTDtif':'gw_depth'}, inplace=True)

# %%
agrodem_input.columns
# Out:
# Index(['Unnamed: 0', 'state', 'lon', 'lat', 'harv_area', 'sw_depth', 'country',
#        'curr_yield', 'max_yield', 'field_1', 'geometry', 'elevation', 'awsc',
#        'prec_1', 'prec_2', 'prec_3', 'prec_4', 'prec_5', 'prec_6', 'prec_7',
#        'prec_8', 'prec_9', 'prec_10', 'prec_11', 'prec_12', 'srad_1', 'srad_2',
#        'srad_3', 'srad_4', 'srad_5', 'srad_6', 'srad_7', 'srad_8', 'srad_9',
#        'srad_10', 'srad_11', 'srad_12', 'tavg_1', 'tavg_2', 'tavg_3', 'tavg_4',
#        'tavg_5', 'tavg_6', 'tavg_7', 'tavg_8', 'tavg_9', 'tavg_10', 'tavg_11',
#        'tavg_12', 'tmax_1', 'tmax_2', 'tmax_3', 'tmax_4', 'tmax_5', 'tmax_6',
#        'tmax_7', 'tmax_8', 'tmax_9', 'tmax_10', 'tmax_11', 'tmax_12', 'tmin_1',
#        'tmin_2', 'tmin_3', 'tmin_4', 'tmin_5', 'tmin_6', 'tmin_7', 'tmin_8',
#        'tmin_9', 'tmin_10', 'tmin_11', 'tmin_12', 'wind_1', 'wind_2', 'wind_3',
#        'wind_4', 'wind_5', 'wind_6', 'wind_7', 'wind_8', 'wind_9', 'wind_10',
#        'wind_11', 'wind_12', 'gw_depth'],
#       dtype='object')

# %%
agrodem_input.head()
# Out:
#    Unnamed: 0 state        lon        lat    harv_area    sw_depth  country  \
# 0           0  Baki  43.375000  10.041667  1188.752358  565.677688  Somalia
# 1           1  Baki  43.458333  10.041667     0.000000  565.677688  Somalia
# 2           2  Baki  43.375000   9.958333    23.133422  565.677688  Somalia
# 3           3  Baki  43.458333   9.958333    19.750705  565.677688  Somalia
# 4           4  Baki  43.375000   9.875000     0.000000  565.677688  Somalia
#
#    curr_yield  max_yield  field_1  ... wind_4 wind_5 wind_6 wind_7 wind_8  \
# 0         360      552.6        0  ...    3.5     3.    5.1    6.4    6.5
# 1         360      552.6        1  ...     3.    3.1    5.2     6.    5.7
# 2         360      552.6        2  ...    3.6     3.     5.    6.3    6.4
# 3         360      552.6        3  ...    3.7     3.    5.3     6.    5.7
# 4         360      552.6        4  ...    3.3     3.    5.1    6.3    6.3
#
#   wind_9 wind_10 wind_11 wind_12   gw_depth
# 0    3.9     3.2     3.6     2.7  6.4200206
# 1    3.9     3.2     3.6     2.7  90.180756
# 2    3.9     3.1     3.4     2.6   37.94693
# 3    3.6     3.2     3.5     2.7  18.235485
# 4    3.8      3.     3.3     2.6   77.85009
#
# [5 rows x 86 columns]

# %%
# Add geometry and convert to spatial dataframe in source CRS
agrodem_input['geometry'] = list(zip(agrodem_input['lon'], agrodem_input['lat']))
agrodem_input['geometry'] = agrodem_input['geometry'].apply(Point)
agrodem_input = gpd.GeoDataFrame(agrodem_input, geometry='geometry', crs={'init': 'epsg:4326'})

#Reproject data in to Ordnance Survey GB coordinates
agrodem_input = agrodem_input.to_crs({'init': 'epsg:3395'})
# Out:
# C:\Users\adm.esa\Anaconda3\envs\OSMNX\lib\site-packages\pyproj\crs\crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
agrodem_input.head()
# Out:
#    Unnamed: 0 state        lon        lat    harv_area    sw_depth  country  \
# 0           0  Baki  43.375000  10.041667  1188.752358  565.677688  Somalia
# 1           1  Baki  43.458333  10.041667     0.000000  565.677688  Somalia
# 2           2  Baki  43.375000   9.958333    23.133422  565.677688  Somalia
# 3           3  Baki  43.458333   9.958333    19.750705  565.677688  Somalia
# 4           4  Baki  43.375000   9.875000     0.000000  565.677688  Somalia
#
#    curr_yield  max_yield  field_1  ... wind_4 wind_5 wind_6 wind_7 wind_8  \
# 0         360      552.6        0  ...    3.5     3.    5.1    6.4    6.5
# 1         360      552.6        1  ...     3.    3.1    5.2     6.    5.7
# 2         360      552.6        2  ...    3.6     3.     5.    6.3    6.4
# 3         360      552.6        3  ...    3.7     3.    5.3     6.    5.7
# 4         360      552.6        4  ...    3.3     3.    5.1    6.3    6.3
#
#   wind_9 wind_10 wind_11 wind_12   gw_depth
# 0    3.9     3.2     3.6     2.7  6.4200206
# 1    3.9     3.2     3.6     2.7  90.180756
# 2    3.9     3.1     3.4     2.6   37.94693
# 3    3.6     3.2     3.5     2.7  18.235485
# 4    3.8      3.     3.3     2.6   77.85009
#
# [5 rows x 86 columns]

# %%
droping_cols = ["Unnamed: 0","geometry"]
agrodem_input.drop(droping_cols, axis=1, inplace=True)

# %% [markdown]
# ## Exporting gdf into csv (or shapefile, gpkg as needed)

# %%
#gpkg
#agrodem_input.to_file("Zambezia_1km.gpkg", layer='Maize_Inputfile', driver="GPKG")

#shp
#agrodem_input.to_file("Moz_250m_Maize_190920.shp")

# Define output path
#path = r"C:\Oluchi\Irrigation model\Output_data\agrodem_input\Final_input_files"
path = r"F:\AgriDem\agrodem_preprocessing\Agrodem_prepping_output"
csvname = "Somalia_agrodem_input_sorghum_10km.csv"

#maize
agrodem_input.to_csv(os.path.join(path,"{c}".format(c=csvname)), index=False)
